# %%
import pandas as pd
df = pd.read_csv("high_semantic_errors.csv", index_col=0)

# %%
df
# Out:
#         image_path                                       ground_truth  \
# 136214         NaN  Bavaria , asked me if I would do something for...
# 138742         NaN  She plays the possessive mother of a man whose...
# 137903         NaN  attractive - interest ! Tiredness has , theref...
# 134832         NaN  the river . The film starts off brightly enoug...
# 138601         NaN    I 'd marry you myself . " Gay laughed , Doc was
# ...            ...                                                ...
# 1597        1597.0          This was too reminiscent of the nursemaid
# 1613        1613.0                night and formed a queue stretching
# 1744        1744.0        play any part in # determining its future .
# 1804        1804.0                    MR. KRUSCHEV raises the bogy of
# 831          831.0  Iain Macleod , Colonial Secretary , and Mr. Du...
#
#                                            predicted_text         cer  \
# ...
