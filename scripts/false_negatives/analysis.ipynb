# %%
import srsly 
data = srsly.read_jsonl("../../evaluation/false_negatives_analysis.jsonl")
data = list(data)

# %%
# remove where analysis is no
yeses = [d for d in data if "yes" in d["analysis"]]
len(data), len(yeses)
# Out:
# (37547, 7)

# %%
yeses
# Out:
# [{'image_path': None,
#   'ground_truth': '" unsatisfactory . " African delegates to the talks yesterday',
#   'predicted_text': '',
#   'cer': 100.0,
#   'wer': 100.0,
#   'semantic_error': None,
#   'kl_divergence': None,
#   'entropy': None,
#   'mean_gt_rank': None,
#   'top5_accuracy': None,
#   'inference_time': 21.0866129398,
#   'error': None,
#   'model': 'chatgpt5_results',
#   'document_score': 0.0,
#   'semantic_error_count': 0,
#   'obvious_error_count': 0,
#   'index': 232.0,
#   'run_date': '2026-03-10',
#   'logprobs': None,
#   'mean_logprob': None,
#   'confidence': None,
#   'image_idx': None,
#   'analysis': 'Yes, the predicted text is missing the words "unsatisfactory", "African", "delegates", "to", "the", "talks", and "yesterday" which are present in the ground truth.'},
#  {'image_path': None,
#   'ground_truth': "the House . Early results in yesterday's",
#   'predicted_text': '',
#   'cer': 100.0,
#   'wer': 100.0,
#   'semantic_error': None,
# ...

# %%
for yes in yeses:
    print(yes["model"])
    print()
# Out:
# chatgpt5_results
#
# chatgpt5_results
#
# chatgpt5_results
#
# chatgpt5_results
#
# chatgpt5_results
#
# tesseract_results
#
# tesseract_results
